# %%
import os
from dotenv import load_dotenv

load_dotenv() 
api_key = os.environ['TOGETHER_API_API_KEY']

# %%
import warnings
import requests
import json
import time
from dotenv import find_dotenv

_ = load_dotenv(find_dotenv())
url = f"https://api.together.xyz/inference"
headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }

def llama(prompt, 
          add_inst=True, 
          model="togethercomputer/llama-2-70b-chat", 
          temperature=0.0, 
          max_tokens=1024,
          verbose=False,
          url=url,
          headers=headers,
          base=2, # number of seconds to wait
          max_tries=3):
    
    if add_inst:
        prompt = f"[INST]{prompt}[/INST]"

    if verbose:
        print(f"Prompt:\n{prompt}\n")
        print(f"model: {model}")

    data = {
            "model": model,
            "prompt": prompt,
            "temperature": temperature,
            "max_tokens": max_tokens
        }

    # Allow multiple attempts to call the API incase of downtime.
    # Return provided response to user after 3 failed attempts.
    wait_seconds = [base**i for i in range(max_tries)]

    for num_tries in range(max_tries):
        try:
            response = requests.post(url, headers=headers, json=data)
            return response.json()['output']['choices'][0]['text']
        except Exception as e:
            if response.status_code != 500:
                return response.json()

            print(f"error message: {e}")
            print(f"response object: {response}")
            print(f"num_tries {num_tries}")
            print(f"Waiting {wait_seconds[num_tries]} seconds before automatically trying again.")
            time.sleep(wait_seconds[num_tries])
 
    print(f"Tried {max_tries} times to make API call to get a valid response object")
    print("Returning provided response")
    return response


def llama_chat(prompts, 
               responses,
               model="togethercomputer/llama-2-7b-chat", 
               temperature=0.0, 
               max_tokens=1024,
               verbose=False,
               url=url,
               headers=headers,
               base=2,
               max_tries=3
              ):

    prompt = get_prompt_chat(prompts,responses)

    # Allow multiple attempts to call the API incase of downtime.
    # Return provided response to user after 3 failed attempts.
    wait_seconds = [base**i for i in range(max_tries)]

    for num_tries in range(max_tries):
        try:
            response = llama(prompt=prompt,
                             add_inst=False,
                             model=model, 
                             temperature=temperature, 
                             max_tokens=max_tokens,
                             verbose=verbose,
                             url=url,
                             headers=headers
                            )
            return response
        except Exception as e:
            if response.status_code != 500:
                return response.json()

            print(f"error message: {e}")
            print(f"response object: {response}")
            print(f"num_tries {num_tries}")
            print(f"Waiting {wait_seconds[num_tries]} seconds before automatically trying again.")
            time.sleep(wait_seconds[num_tries])
 
    print(f"Tried {max_tries} times to make API call to get a valid response object")
    print("Returning provided response")
    return response


def get_prompt_chat(prompts, responses):
  prompt_chat = f"<s>[INST] {prompts[0]} [/INST]"
  for n, response in enumerate(prompts):
    prompt = prompts[n + 1]
    prompt_chat += f"\n{response}\n </s><s>[INST] \n{ prompt }\n [/INST]"

  return prompt_chat

# %%
with open("../data/cbp-lkg/data/SIMILARITY/MAPPING.json") as f:
    mapping = json.loads(f.read())

dict_mapping = {f'{mapping[k]}':k for k in mapping}

# %%
with open("../data/cbp-lkg/data/SIMILARITY/similarity_demo_file.json") as f:
    similarity_data = json.loads(f.read())

# %%
similarity_pairs = similarity_data[0]['links_train']
similarity_pairs[:5]
# Out:
# [['798', '719'],
#  ['799', '670'],
#  ['800', '840'],
#  ['801', '840'],
#  ['802', '176']]

# %%
doc_pairs = []

for pair in similarity_pairs:
    [_s, _o] = pair
    s = dict_mapping[_s]
    o = dict_mapping[_o]
    doc_pairs.append((s, o))

doc_pairs[:5]
# Out:
# [('1206754', '795465'),
#  ('51545606', '997135'),
#  ('1735815', '1857950'),
#  ('383397', '1857950'),
#  ('60799', '1844910')]

# %%
cases = list(set(mapping.keys()))
cases[:10]
# Out:
# ['1857950',
#  '119540048',
#  '1407895',
#  '743328',
#  '211970',
#  '371933',
#  '685234',
#  '820931',
#  '198827109',
#  '1633179']

# %%
import random

random.seed(42)
documents_random = random.sample(list(cases), 50)
print(documents_random)
# Out:
# ['91635', '374340', '1132299', '70487596', '60799', '380655', '1213021', '623494', '1334665', '611025', '795465', '31239895', '139299795', '248715', '1239673', '113963352', '1878548', '314044', '138192511', '14898186', '1165503', '8919089', '110813550', '4354', '54865315', '7926018', '174974', '1586918', '115718142', '1877956', '1548289', '155579055', '36937', '1035719', '856194', '938898', '919121', '685234', '1822024', '1418391', '1011356', '491934', '1328814', '1767393', '800341', '1462242', '1401567', '399708', '1543623', '1006709']

# %%
import pandas as pd

case_details_df = pd.read_csv('../data/cbp-lkg/data/SIMILARITY/MERGED_RESULT.csv')
case_details_df
# Out:
#            tid              PERSON      NORP                ORG  \
# 0       928322           V P Anand    Indian              State
# 1       699319            Bhandare  T V S N      the High Court
# 2      1988649          Rani Kusum         -              Court
# 3      1362442               Gupta         -              Court
# 4       357132               Patil    Indian     the High Court
# ..         ...                 ...       ...                ...
# 953   12050516  Shri H K Choudhary    Indian                TPO
# 954  123737198        Sanjay Dalia    Indian  the Supreme Court
# 955    1307808       Oswal Woollen         -     the High Court
# 956    1747781              Ganesh    Indian            Company
# 957     330608               Antox         -              Antox
#
#                           FAC        GPE       LOC                    PRODUCT  \
# 0                  Bombay 133      India         -                   Gunpower
# 1                         123      India  District                          -
# 2                           -     Rampur         -                          -
# 3                           -  RAMASWAMY         -                       Addl
# 4          the Mohol Sub Jail    Baburao         -                          -
# ..                        ...        ...       ...                        ...
# 953          the Mumbai Bench      Delhi         -           No 4791 Del 2015
# 954          Community Centre    Deogarh         -                          -
# 955         the Calcutta Port  Ahmedabad         -                          -
# 956                 Delhi 329  Hyderabad         -                   Class 34
# 957  the Trade Mark Cal De Ce     Bombay         -  Calcium Gluconate Tablets
#
#     EVENT          WORK_OF_ART  ... /location/geography /other/percent  \
# 0       -  The State of Madras  ...    the central govt              -
# 1       -                Misc   ...            district              -
# 2       -                    -  ...                   -              -
# 3       -                 J D   ...                   -            12
# 4       -               D S P   ...                   -              -
# ..    ...                  ...  ...                 ...            ...
# 953     -    Lump Sum Turn Key  ...            assessee           100
# 954     -         Dhodha House  ...                   -              -
# 955     -                    -  ...                   -              -
# 956     -    Edwards Vs Dennis  ...          trade mark              -
# 957     -        Special Leave  ...                   -              -
#
#     /finance/currency /location/structure /id/ip_address /other/organization  \
# 0         40 per cent           l q r 518              -                 ipc
# 1                   -                   -              -               court
# 2                   -              rule 1              -               court
# 3               2 000              rule 4              -               court
# 4                   -  the mohol sub jail              -               court
# ..                ...                 ...            ...                 ...
# 953                 -          rule 10b 3              -                   -
# 954                 -         nipun tower              -                   -
# 955                 -       oswal woollen              -      the high court
# 956       trade marks         sections 46              -     the trade marks
# 957                 -                   -              -               antox
#
#                                                  title  \
# 0    Ajay Agarwal vs Union Of India And Ors on 5 Ma...
# 1    S.M.D. Kiran Pasha vs Government Of Andhra Pra...
# 2    Smt. Rani Kusum vs Smt. Kanchan Devi And Ors o...
# 3    Desh Bandhu Gupta vs N.L.Anand & Rajinder Sing...
# 4    Baburao Bajirao Patil vs State Of Maharashtra ...
# ..                                                 ...
# 953  Terex India Pvt. Ltd., Tamil Nadu vs Dcit, New...
# 954  Ultra Home Construction Pvt. Ltd vs Purushotta...
# 955  Union Of India & Ors vs Adani Exports Ltd. & A...
# 956  Vishnudas Trading As Vishnudas vs The Vazir Su...
# 957  Wander Ltd. And Anr. vs Antox India P. Ltd. on...
#
#                                  docsource  \
# 0                   Supreme Court of India
# 1                   Supreme Court of India
# 2                   Supreme Court of India
# 3                   Supreme Court of India
# 4                   Supreme Court of India
# ..                                     ...
# 953  Income Tax Appellate Tribunal - Delhi
# 954                       Delhi High Court
# 955                 Supreme Court of India
# 956                 Supreme Court of India
# 957                 Supreme Court of India
#
#                                                   acts infringement
# 0    indian penal code\ncode of criminal procedure ...            0
# 1    essential commodities act\nconservation of for...            1
# 2    code of civil procedure\nconsumer protection a...            0
# 3                                                  NaN            0
# 4                                indian evidence act\n            0
# ..                                                 ...          ...
# 953                                    incometax act\n            1
# 954  code of civil procedure\ncopyright act\ntrade ...            1
# 955                                                  -            0
# 956  general clauses act\ncopyright act\ntrade mark...            1
# 957  drugs and cosmetics act\ndrugs and cosmetics r...            1
#
# [958 rows x 42 columns]

# %%
# %%writefile ../legal-text-extract-for-summarization.sh
#
# #!/bin/bash
#
# source_dir="../data/cbp-lkg/data/LEGAL_TEXT/"
# destination_dir="../results/case-similarity-text/for-summarization"
#
# mkdir -p "$destination_dir"
#
# for file in "$source_dir"/*.txt; do
#     filename=$(basename -- "$file")
#     destination_path="$destination_dir/$filename"
#     cat "$file" | ag "\S" | head -n 50 | tail -n +20 > "$destination_path"
#     if [ "$(wc -l < "$source_dir$filename")" -gt 30 ]; then
#       cat "$file" | ag "\S" | tail -n 20 | head -n -4 >> "$destination_path"
#     fi
#     echo "Wrote $destination_path ..."
# done

# %%
# !chmod +x ../legal-text-extract-for-summarization.sh
# !../legal-text-extract-for-summarization.sh | tail

# %%
case_details_df[case_details_df['tid'] == 123737198]['title'].shape[0]
# Out:
# 1

# %%
import numpy as np

def get_example(doc_id):
    case_name_df = case_details_df[case_details_df['tid'] == doc_id].reset_index(drop=True)['title']
    s = ''
    if case_name_df.shape[0] == 1:
        s += '### Case Name: ' + case_details_df[case_details_df['tid'] == doc_id].reset_index(drop=True)['title'][0]
    with open(f'../results/case-similarity-text/tail/{doc_id}.txt') as f:
        s += '\n### Judgment Excerpt: ' + f.read()
    acts_df = case_details_df[case_details_df['tid'] == doc_id].reset_index(drop=True)['acts']
    if acts_df.shape[0] == 1:
        acts = acts_df[0]
        if acts != np.nan and len(acts) > 0 and acts != '-':
            s += '### Acts Mentioned: ' + str(acts.split('\n')[:-1])
    return s

# %%
print(get_example(123737198))
# Out:
# ### Case Name: Ultra Home Construction Pvt. Ltd vs Purushottam Kumar Chaubey & Ors on 20 January, 2016
# ### Judgment Excerpt: > backdrop of the observations in Dhodha House (supra), the appellant /
# > plaintiff carries on business in Deogarh, Jharkhand. It may also carry on
# > business at Delhi. But, because the cause of action has allegedly arisen in
# > Deogarh, Jharkhand, and not in Delhi, the appellant/plaintiff cannot sue the
# > defendants/respondents in Delhi in view of the decision in Sanjay Dalia
# > (supra). Thus, this court does not have the territorial jurisdiction to
# > entertain the suit. And, on this count, the decision of the learned single
# > judge cannot be faulted. But, the suit ought not to have been dismissed. As
# > FAO (OS) 494/15 Page 25 of 26 this court did not have jurisdiction, the
# > plaint ought to have been returned under order 7 rule 10 CPC. Only to that
# > extent, the learned single judge had erred.
# 19\. In sum, the dismissal of the suit is set aside. Since this court does not
# have the territorial jurisdiction to entertain the suit, the plaint is
# directed to be returned to the appellant/plaintiff for presentation before the
# proper court. The appeal stands disposed of. The parties shall bear their own
# costs.
#                                               BADAR DURREZ AHMED, J
#     JANUARY 20, 2016                             SANJEEV SACHDEVA, J
#     HJ
#     FAO (OS) 494/15                                                      Page 26 of 26
# ### Acts Mentioned: ['code of civil procedure', 'copyright act', 'trade marks act']

# %%
def get_prompt(id):
    p = f'''You are given a part of a court judgment along with which case it belongs to. You are a legal expert.

{get_example(id)}

Write a summary of this court judgment.'''
    return p

# %%
print(get_prompt(123737198))
# Out:
# You are given a part of a court judgment along with which case it belongs to. You are a legal expert.
#
# ### Case Name: Ultra Home Construction Pvt. Ltd vs Purushottam Kumar Chaubey & Ors on 20 January, 2016
# ### Judgment Excerpt: > backdrop of the observations in Dhodha House (supra), the appellant /
# > plaintiff carries on business in Deogarh, Jharkhand. It may also carry on
# > business at Delhi. But, because the cause of action has allegedly arisen in
# > Deogarh, Jharkhand, and not in Delhi, the appellant/plaintiff cannot sue the
# > defendants/respondents in Delhi in view of the decision in Sanjay Dalia
# > (supra). Thus, this court does not have the territorial jurisdiction to
# > entertain the suit. And, on this count, the decision of the learned single
# > judge cannot be faulted. But, the suit ought not to have been dismissed. As
# > FAO (OS) 494/15 Page 25 of 26 this court did not have jurisdiction, the
# > plaint ought to have been returned under order 7 rule 10 CPC. Only to that
# > extent, the learned single judge had erred.
# 19\. In sum, the dismissal of the suit is set aside. Since this court does not
# have the territorial jurisdiction to entertain the suit, the plaint is
# directed to be returned to the appellant/plaintiff for presentation before the
# proper court. The appeal stands disposed of. The parties shall bear their own
# costs.
#                                               BADAR DURREZ AHMED, J
#     JANUARY 20, 2016                             SANJEEV SACHDEVA, J
#     HJ
#     FAO (OS) 494/15                                                      Page 26 of 26
# ### Acts Mentioned: ['code of civil procedure', 'copyright act', 'trade marks act']
#
# Write a summary of this court judgment.

# %%
response = llama(get_prompt(123737198), verbose=True)
# Out:
# Prompt:
# [INST]You are given a part of a court judgment along with which case it belongs to. You are a legal expert.
#
# ### Case Name: Ultra Home Construction Pvt. Ltd vs Purushottam Kumar Chaubey & Ors on 20 January, 2016
# ### Judgment Excerpt: > backdrop of the observations in Dhodha House (supra), the appellant /
# > plaintiff carries on business in Deogarh, Jharkhand. It may also carry on
# > business at Delhi. But, because the cause of action has allegedly arisen in
# > Deogarh, Jharkhand, and not in Delhi, the appellant/plaintiff cannot sue the
# > defendants/respondents in Delhi in view of the decision in Sanjay Dalia
# > (supra). Thus, this court does not have the territorial jurisdiction to
# > entertain the suit. And, on this count, the decision of the learned single
# > judge cannot be faulted. But, the suit ought not to have been dismissed. As
# > FAO (OS) 494/15 Page 25 of 26 this court did not have jurisdiction, the
# > plaint ought to have been returned under order 7 rule 10 CPC. Only to that
# > extent, the learned single judge had erred.
# 19\. In sum, the dismissal of the suit is set aside. Since this court does not
# have the territorial jurisdiction to entertain the suit, the plaint is
# directed to be returned to the appellant/plaintiff for presentation before the
# proper court. The appeal stands disposed of. The parties shall bear their own
# costs.
#                                               BADAR DURREZ AHMED, J
#     JANUARY 20, 2016                             SANJEEV SACHDEVA, J
#     HJ
#     FAO (OS) 494/15                                                      Page 26 of 26
# ### Acts Mentioned: ['code of civil procedure', 'copyright act', 'trade marks act']
#
# Write a summary of this court judgment.[/INST]
#
# model: togethercomputer/llama-2-70b-chat

# %%
print(response)
# Out:
#   The court judgment is for the case "Ultra Home Construction Pvt. Ltd vs Purushottam Kumar Chaubey & Ors" and it pertains to the issue of territorial jurisdiction of a court to entertain a suit. The appellant/plaintiff, Ultra Home Construction Pvt. Ltd, carries on business in Deogarh, Jharkhand and also has a branch office in Delhi. The defendants/respondents, Purushottam Kumar Chaubey and others, are residents of Delhi. The cause of action for the suit allegedly arose in Deogarh, Jharkhand, and not in Delhi. Therefore, the court held that it does not have the territorial jurisdiction to entertain the suit as per the decision in Sanjay Dalia (supra).
#
# The court further held that the suit ought not to have been dismissed but instead, the plaint should have been returned to the appellant/plaintiff for presentation before the proper court. The court directed the return of the plaint to the appellant/plaintiff and disposed of the appeal. The parties were directed to bear their own costs.
#
# In summary, the court judgment states that the court does not have the territorial jurisdiction to entertain a suit if the cause of action has not arisen within its jurisdiction, and in such cases, the plaint should be returned to the plaintiff for presentation before the proper court.

# %%
from tqdm.notebook import tqdm

prompts = []
summaries = []

for doc_id in tqdm(documents_random):
    prompt = get_prompt(doc_id)
    response = llama(prompt)
    prompts.append(prompt)
    summaries.append(response)
    # except:
    #     print('Error: ' + doc_id)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
summaries_df = pd.DataFrame({
    'jid': documents_random,
    'prompt': [f'[INST]{p}[/INST]' for p in prompts],
    'summary': summaries
})
summaries_df
# Out:
#           jid                                             prompt  \
# 0       91635  [INST]You are given a part of a court judgment...
# 1      374340  [INST]You are given a part of a court judgment...
# 2     1132299  [INST]You are given a part of a court judgment...
# 3    70487596  [INST]You are given a part of a court judgment...
# 4       60799  [INST]You are given a part of a court judgment...
# 5      380655  [INST]You are given a part of a court judgment...
# 6     1213021  [INST]You are given a part of a court judgment...
# 7      623494  [INST]You are given a part of a court judgment...
# 8     1334665  [INST]You are given a part of a court judgment...
# 9      611025  [INST]You are given a part of a court judgment...
# 10     795465  [INST]You are given a part of a court judgment...
# 11   31239895  [INST]You are given a part of a court judgment...
# 12  139299795  [INST]You are given a part of a court judgment...
# 13     248715  [INST]You are given a part of a court judgment...
# 14    1239673  [INST]You are given a part of a court judgment...
# 15  113963352  [INST]You are given a part of a court judgment...
# 16    1878548  [INST]You are given a part of a court judgment...
# 17     314044  [INST]You are given a part of a court judgment...
# 18  138192511  [INST]You are given a part of a court judgment...
# 19   14898186  [INST]You are given a part of a court judgment...
# 20    1165503  [INST]You are given a part of a court judgment...
# 21    8919089  [INST]You are given a part of a court judgment...
# 22  110813550  [INST]You are given a part of a court judgment...
# 23       4354  [INST]You are given a part of a court judgment...
# 24   54865315  [INST]You are given a part of a court judgment...
# 25    7926018  [INST]You are given a part of a court judgment...
# 26     174974  [INST]You are given a part of a court judgment...
# 27    1586918  [INST]You are given a part of a court judgment...
# 28  115718142  [INST]You are given a part of a court judgment...
# 29    1877956  [INST]You are given a part of a court judgment...
# 30    1548289  [INST]You are given a part of a court judgment...
# 31  155579055  [INST]You are given a part of a court judgment...
# 32      36937  [INST]You are given a part of a court judgment...
# 33    1035719  [INST]You are given a part of a court judgment...
# 34     856194  [INST]You are given a part of a court judgment...
# 35     938898  [INST]You are given a part of a court judgment...
# 36     919121  [INST]You are given a part of a court judgment...
# 37     685234  [INST]You are given a part of a court judgment...
# 38    1822024  [INST]You are given a part of a court judgment...
# 39    1418391  [INST]You are given a part of a court judgment...
# 40    1011356  [INST]You are given a part of a court judgment...
# 41     491934  [INST]You are given a part of a court judgment...
# 42    1328814  [INST]You are given a part of a court judgment...
# 43    1767393  [INST]You are given a part of a court judgment...
# 44     800341  [INST]You are given a part of a court judgment...
# 45    1462242  [INST]You are given a part of a court judgment...
# 46    1401567  [INST]You are given a part of a court judgment...
# 47     399708  [INST]You are given a part of a court judgment...
# 48    1543623  [INST]You are given a part of a court judgment...
# 49    1006709  [INST]You are given a part of a court judgment...
#
#                                               summary
# 0     The court judgment is about a dispute over a...
# 1     The court judgment is regarding an appeal ag...
# 2     The court judgment is regarding a trade mark...
# 3     This court judgment is regarding an applicat...
# 4     The Supreme Court of India allowed several c...
# 5     The court judgment is regarding a case where...
# 6     The Supreme Court of India has allowed the c...
# 7     The court judgment is regarding an appeal ag...
# 8     The summary of this court judgment is that t...
# 9     This court judgment is allowing an appeal in...
# 10    The Supreme Court of India has delivered a j...
# 11    The court judgment is a ruling on a bail app...
# 12    The court judgment is a decision made by the...
# 13    The court judgment is a summary of a civil a...
# 14    The court judgment allows an appeal and sets...
# 15    The appellants, defendants in the original s...
# 16    The Supreme Court of India has allowed an ap...
# 17    The court judgment is regarding the validity...
# 18    This court judgment is regarding a copyright...
# 19    This court judgment is regarding a dispute o...
# 20    The court judgment is in favor of the assess...
# 21    The court judgment is a ruling on an applica...
# 22    The judgment excerpt provided is from the ca...
# 23    The court judgment is in favor of the petiti...
# 24    The court judgment is a writ appeal case (W....
# 25    The judgment is a partial allowance of an ap...
# 26    The judgment is in regards to a case where t...
# 27    The appellant had requested a new judge to t...
# 28    This court judgment is in regards to two ori...
# 29    The court judgment is regarding an exemption...
# 30    The Supreme Court of India allowed an appeal...
# 31    The judgment appears to be related to a case...
# 32    The court judgment is regarding an appeal ag...
# 33    The appellant, Dr. Vimla, was accused of def...
# 34    The court judgment is regarding a case of se...
# 35    The court judgment is discussing the concept...
# 36    The judgment is regarding a challenge to the...
# 37    The court judgment is regarding an appeal ag...
# 38    The appellant and respondents were involved ...
# 39    The court judgment is regarding the liabilit...
# 40    The court judgment is regarding a dispute be...
# 41    The court judgment is regarding a dispute be...
# 42    The court judgment is about a dispute regard...
# 43    The summary of this court judgment is that t...
# 44    This court judgment is in regards to a case ...
# 45    The summary of this court judgment is as fol...
# 46    The court judgment is regarding a case where...
# 47    The court judgment is about a case where the...
# 48    The court judgment is in regards to an appea...
# 49    The court judgment is regarding an appeal ag...

# %%
summaries_df.to_csv('../results/case-similarity-summaries-llama2-70b-chat-030324-final.csv', index=False)
